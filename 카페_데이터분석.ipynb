# %%
#한글오류

# 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 설정
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.rc('axes', unicode_minus=False)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 3s (3,814 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager,rc
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
temp = pd.read_csv('/content/drive/My Drive/data/coffee/소상공인시장진흥공단_상가(상권)정보_인천_202012.csv',sep='|',encoding='utf-8')
temp
# Out:
#           상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0       17175369  박서방네목로주점  NaN         Q       음식       Q01        한식
# 1       27647863     홍가네맛집  NaN         Q       음식       Q09      유흥주점
# 2       23498449      츄로하임  NaN         Q       음식       Q01        한식
# 3       22882934     간석미용실  NaN         F    생활서비스       F01   이/미용/건강
# 4       24444979        라헬  NaN         D       소매       D05      의복의류
# ...          ...       ...  ...       ...      ...       ...       ...
# 118453  17214333     아이지에이  논현점         D       소매       D03     종합소매점
# 118454  17214671   땡이네애견용품  NaN         D       소매       D09  애견/애완/동물
# 118455  17221174     인생건어물  NaN         D       소매       D01   음/식료품소매
# 118456  17221206     착한건어물  NaN         D       소매       D01   음/식료품소매
# 118457  17207622     더어려지다  NaN         F    생활서비스       F01   이/미용/건강
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# ...

# %%
#폴더에 있는 모든 csv 읽기 Glob 활용
from glob import glob

file_names = glob("/content/drive/My Drive/data/coffee/*.csv")
total = pd.DataFrame()

# %%
# 폴더내 csv 병합
for file_name in file_names:
  temp= pd.read_csv(file_name, sep='|',encoding='utf-8')
  total= pd.concat([total,temp])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
total
# Out:
#          상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0      17163092   도전최강달인왕만두  NaN         Q       음식       Q01         한식
# 1      17120456          이때  NaN         Q       음식       Q01         한식
# 2      17175350       L.A.D  NaN         Q       음식       Q01         한식
# 3      17175311     제이씨에스푸드  NaN         Q       음식       Q01         한식
# 4      22767534      BYC상신점  상신점         D       소매       D05       의복의류
# ...         ...         ...  ...       ...      ...       ...        ...
# 46488  17227204  공감공인중개사사무소  NaN         L      부동산       L01      부동산중개
# 46489  17227317    장원부동산컨설팅  NaN         L      부동산       L01      부동산중개
# 46490  17212547      조이힐하우스  NaN         O       숙박       O02  모텔/여관/여인숙
# 46491  17211770       가보면호프  NaN         Q       음식       Q09       유흥주점
# 46492  17212910    토스카나바이달팡  NaN         F    생활서비스       F01    이/미용/건강
#
#       상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호     건물명  \
# ...

# %%
# 인덱스가 중복되어 리셋  / 중복 인덱스 제거 drop=True
total.reset_index(inplace=True)

# %%
total
# Out:
#          index    상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0            0  17163092   도전최강달인왕만두  NaN         Q       음식       Q01
# 1            1  17120456          이때  NaN         Q       음식       Q01
# 2            2  17175350       L.A.D  NaN         Q       음식       Q01
# 3            3  17175311     제이씨에스푸드  NaN         Q       음식       Q01
# 4            4  22767534      BYC상신점  상신점         D       소매       D05
# ...        ...       ...         ...  ...       ...      ...       ...
# 2416247  46488  17227204  공감공인중개사사무소  NaN         L      부동산       L01
# 2416248  46489  17227317    장원부동산컨설팅  NaN         L      부동산       L01
# 2416249  46490  17212547      조이힐하우스  NaN         O       숙박       O02
# 2416250  46491  17211770       가보면호프  NaN         Q       음식       Q09
# 2416251  46492  17212910    토스카나바이달팡  NaN         F    생활서비스       F01
#
#           상권업종중분류명 상권업종소분류코드   상권업종소분류명  ...                     건물관리번호  \
# ...

# %%
data=total[['상호명','지점명','상권업종대분류명','상권업종중분류명','시도명','시군구명','행정동명','경도','위도']]

data
# Out:
#                 상호명  지점명 상권업종대분류명   상권업종중분류명      시도명  시군구명  행정동명          경도  \
# 0         도전최강달인왕만두  NaN       음식         한식    서울특별시   강동구  고덕2동  127.159471
# 1                이때  NaN       음식         한식    서울특별시   마포구   연남동  126.924660
# 2             L.A.D  NaN       음식         한식    서울특별시   마포구   서교동  126.919845
# 3           제이씨에스푸드  NaN       음식         한식    서울특별시   관악구   서림동  126.937790
# 4            BYC상신점  상신점       소매       의복의류    서울특별시   송파구  거여2동  127.147321
# ...             ...  ...      ...        ...      ...   ...   ...         ...
# 2416247  공감공인중개사사무소  NaN      부동산      부동산중개  제주특별자치도  서귀포시   표선면  126.808099
# 2416248    장원부동산컨설팅  NaN      부동산      부동산중개  제주특별자치도  서귀포시   중문동  126.446092
# 2416249      조이힐하우스  NaN       숙박  모텔/여관/여인숙  제주특별자치도   제주시   애월읍  126.394059
# 2416250       가보면호프  NaN       음식       유흥주점  제주특별자치도   제주시  용담2동  126.510712
# 2416251    토스카나바이달팡  NaN    생활서비스    이/미용/건강  제주특별자치도  서귀포시   대천동  126.484653
#
#                 위도
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416252 entries, 0 to 2416251
# Data columns (total 9 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   상호명       object
#  1   지점명       object
#  2   상권업종대분류명  object
#  3   상권업종중분류명  object
#  4   시도명       object
#  5   시군구명      object
#  6   행정동명      object
#  7   경도        float64
#  8   위도        float64
# dtypes: float64(2), object(7)
# memory usage: 165.9+ MB

# %%
#데이터 용량 줄이기
del total

# %%
#set(data["상권업종대분류명"])
set(data["상권업종중분류명"])
# Out:
# {'PC/오락/당구/볼링등',
#  '가구소매',
#  '가방/신발/액세서리',
#  '가전제품소매',
#  '가정/주방/인테리어',
#  '개인/가정용품수리',
#  '개인서비스',
#  '건강/미용식품',
#  '경마/경륜/성인오락',
#  '광고/인쇄',
#  '기타교육기관',
#  '기타서비스업',
#  '기타음식업',
#  '기타판매업',
#  '놀이/여가/취미',
#  '닭/오리요리',
#  '대중목욕탕/휴게',
#  '대행업',
#  '도서관/독서실',
#  '모텔/여관/여인숙',
#  '무도/유흥/가무',
#  '물품기기대여',
#  '민박/하숙',
#  '법무세무회계',
#  '별식/퓨전요리',
#  '부동산관련서비스',
#  '부동산임대',
#  '부동산중개',
#  '부페',
#  '분식',
#  '분양',
#  '사무/문구/컴퓨터',
#  '사진',
#  '사진/광학/정밀기기소매',
#  '선물/팬시/기념품',
#  '세탁/가사서비스',
#  '스포츠/운동',
#  '시계/귀금속소매',
#  '실내운동시설',
#  '실외운동시설',
#  '애견/애완/동물',
#  '양식',
#  '연구소',
#  '연극/영화/극장',
#  '예술품/골동품/수석/분재',
#  '예식/의례/관혼상제',
#  '요가/단전/마사지',
#  '운동/경기용품소매',
#  '운송/배달/택배',
#  '운영관리시설',
#  '유스호스텔',
#  '유아교육',
#  '유아용품',
#  '유흥주점',
#  '음/식료품소매',
#  '음식배달서비스',
#  '의복의류',
#  '의약/의료품소매',
#  '이/미용/건강',
#  '인력/고용/용역알선',
#  '일식/수산물',
#  '자동차/이륜차',
#  '자동차/자동차용품',
#  '장례/묘지',
#  '전시/관람',
#  '제과제빵떡케익',
#  '종교용품판매',
#  '종합소매점',
#  '주유소/충전소',
#  '주택수리',
#  '중고품소매/교환',
#  '중식',
#  '책/서적/도서',
# ...

# %%
df_coffee = data[data["상권업종중분류명"] == "커피점/카페"]

print("전국 커피 전문점 점포 수 : ", len(df_coffee))
df_coffee.head()
# Out:
# 전국 커피 전문점 점포 수 :  113705
#           상호명          지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명          경도  \
# 37        커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시  종로구   혜화동  127.000171
# 129     요거프레소          쌍문점       음식   커피점/카페  서울특별시  도봉구  쌍문2동  127.034746
# 280  406번째스토브          NaN       음식   커피점/카페  서울특별시  양천구   목1동  126.874168
# 281     로얄커피숍          NaN       음식   커피점/카페  서울특별시  강동구  성내2동  127.124193
# 297    빈트리망원점          망원점       음식   커피점/카페  서울특별시  마포구  망원1동  126.899339
#
#             위도
# 37   37.583149
# 129  37.658728
# 280  37.525177
# 281  37.534901
# 297  37.556041

# %%
df_coffee.index=range(len(df_coffee))

# %%
print("전국 커피 전문점 점포 수 : ", len(df_coffee))
df_coffee
# Out:
# 전국 커피 전문점 점포 수 :  113705
#              상호명          지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명  \
# 0            커피빈  코리아대학로대명거리점       음식   커피점/카페    서울특별시   종로구   혜화동
# 1          요거프레소          쌍문점       음식   커피점/카페    서울특별시   도봉구  쌍문2동
# 2       406번째스토브          NaN       음식   커피점/카페    서울특별시   양천구   목1동
# 3          로얄커피숍          NaN       음식   커피점/카페    서울특별시   강동구  성내2동
# 4         빈트리망원점          망원점       음식   커피점/카페    서울특별시   마포구  망원1동
# ...          ...          ...      ...      ...      ...   ...   ...
# 113700    아트앤디자인          NaN       음식   커피점/카페  제주특별자치도   제주시   한림읍
# 113701   솔트스톤골드점          NaN       음식   커피점/카페  제주특별자치도   제주시   삼양동
# 113702     구움디저트          NaN       음식   커피점/카페  제주특별자치도   제주시   노형동
# 113703    우필립시네마          NaN       음식   커피점/카페  제주특별자치도  서귀포시   대정읍
# 113704        카페          루브르       음식   커피점/카페  제주특별자치도   제주시  일도2동
#
#                 경도         위도
# 0       127.000171  37.583149
# 1       127.034746  37.658728
# ...

# %%
set(data["시도명"])
# Out:
# {'강원도',
#  '경기도',
#  '경상남도',
#  '경상북도',
#  '광주광역시',
#  '대구광역시',
#  '대전광역시',
#  '부산광역시',
#  '서울특별시',
#  '세종특별자치시',
#  '울산광역시',
#  '인천광역시',
#  '전라남도',
#  '전라북도',
#  '제주특별자치도',
#  '충청남도',
#  '충청북도'}

# %%
df_seoul_coffe = data[(data["상권업종중분류명"] == "커피점/카페") & (data["시도명"] == "서울특별시")]
df_seoul_coffe.index=range(len(df_seoul_coffe))                      
print("서울시 커피 전문점 점포 수 : ", len(df_seoul_coffe))
df_seoul_coffe
# Out:
# 서울시 커피 전문점 점포 수 :  22239
#              상호명          지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명   행정동명  \
# 0            커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시   종로구    혜화동
# 1          요거프레소          쌍문점       음식   커피점/카페  서울특별시   도봉구   쌍문2동
# 2       406번째스토브          NaN       음식   커피점/카페  서울특별시   양천구    목1동
# 3          로얄커피숍          NaN       음식   커피점/카페  서울특별시   강동구   성내2동
# 4         빈트리망원점          망원점       음식   커피점/카페  서울특별시   마포구   망원1동
# ...          ...          ...      ...      ...    ...   ...    ...
# 22234  로컬스티치북앤커피          NaN       음식   커피점/카페  서울특별시  영등포구  영등포본동
# 22235       카페시모          NaN       음식   커피점/카페  서울특별시   동작구  노량진2동
# 22236       만랩커피         오금역점       음식   커피점/카페  서울특별시   송파구   가락본동
# 22237      레프트커피          NaN       음식   커피점/카페  서울특별시  동대문구    회기동
# 22238      더쌍화커피          NaN       음식   커피점/카페  서울특별시   노원구   중계4동
#
#                경도         위도
# 0      127.000171  37.583149
# 1      127.034746  37.658728
# 2      126.874168  37.525177
# ...

# %%
df_coffee["상호명"].str.contains("스타벅스")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 113700    False
# 113701    False
# 113702    False
# 113703    False
# 113704    False
# Name: 상호명, Length: 113705, dtype: bool

# %% [markdown]
# # 스타벅스

# %%
df_starbucks =  df_coffee[df_coffee["상호명"].str.contains("스타벅스")]
df_starbucks.index =range(len(df_starbucks))
print("전국 스벅 전문점 점포 수 : ", len(df_starbucks))
df_starbucks
# Out:
# 전국 스벅 전문점 점포 수 :  1613
#               상호명        지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명  \
# 0            스타벅스       대학로점       음식   커피점/카페    서울특별시   종로구   이화동
# 1            스타벅스        한티점       음식   커피점/카페    서울특별시   강남구  대치4동
# 2            스타벅스     동숭로아트점       음식   커피점/카페    서울특별시   종로구   이화동
# 3     스타벅스남부터미널2점    남부터미널2점       음식   커피점/카페    서울특별시   서초구  서초3동
# 4            스타벅스      가로수길점       음식   커피점/카페    서울특별시   강남구   신사동
# ...           ...        ...      ...      ...      ...   ...   ...
# 1608  스타벅스제주애월DT점    제주애월DT점       음식   커피점/카페  제주특별자치도   제주시   애월읍
# 1609    스타벅스서귀포DT        NaN       음식   커피점/카페  제주특별자치도  서귀포시   대천동
# 1610         스타벅스  제주서해안로디티점       음식   커피점/카페  제주특별자치도   제주시  용담2동
# 1611    스타벅스제주노형점      제주노형점       음식   커피점/카페  제주특별자치도   제주시   노형동
# 1612         스타벅스     제주서귀포점       음식   커피점/카페  제주특별자치도  서귀포시   중앙동
#
#               경도         위도
# 0     127.002233  37.582185
# 1     127.053715  37.497946
# 2     127.003887  37.582964
# ...

# %%
df_seoul_starbucks =  df_starbucks[df_starbucks["시도명"]=="서울특별시"]
df_seoul_starbucks.index =range(len(df_seoul_starbucks))
print("서울 스벅 전문점 점포 수 : ", len(df_seoul_starbucks))
df_seoul_starbucks.head()
# Out:
# 서울 스벅 전문점 점포 수 :  509
#            상호명      지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명          경도  \
# 0         스타벅스     대학로점       음식   커피점/카페  서울특별시  종로구   이화동  127.002233
# 1         스타벅스      한티점       음식   커피점/카페  서울특별시  강남구  대치4동  127.053715
# 2         스타벅스   동숭로아트점       음식   커피점/카페  서울특별시  종로구   이화동  127.003887
# 3  스타벅스남부터미널2점  남부터미널2점       음식   커피점/카페  서울특별시  서초구  서초3동  127.014198
# 4         스타벅스    가로수길점       음식   커피점/카페  서울특별시  강남구   신사동  127.021629
#
#           위도
# 0  37.582185
# 1  37.497946
# 2  37.582964
# 3  37.484386
# 4  37.523184

# %% [markdown]
# # 이디야 커피

# %%
df_ediya =  df_coffee[df_coffee["상호명"].str.contains("이디야")]
df_ediya.index =range(len(df_ediya))
print("전국 이디야 전문점 점포 수 : ", len(df_ediya))
df_ediya
# Out:
# 전국 이디야 전문점 점포 수 :  2238
#              상호명       지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명          경도  \
# 0          이디야커피      신길역점       음식   커피점/카페    서울특별시  영등포구  신길1동  126.918062
# 1          이디야커피      북창동점       음식   커피점/카페    서울특별시    중구   소공동  126.977556
# 2          이디야커피      라이프점       음식   커피점/카페    서울특별시  영등포구   여의동  126.939198
# 3          이디야커피       시흥점       음식   커피점/카페    서울특별시   금천구  시흥2동  126.913646
# 4     이디야커피양재AT점     양재AT점       음식   커피점/카페    서울특별시   서초구  양재2동  127.040265
# ...          ...       ...      ...      ...      ...   ...   ...         ...
# 2233       이디야커피      송악산점       음식   커피점/카페  제주특별자치도  서귀포시   대정읍  126.289755
# 2234       이디야커피       중앙점       음식   커피점/카페  제주특별자치도   제주시  일도1동  126.526069
# 2235       이디야커피   시청고산동산점       음식   커피점/카페  제주특별자치도   제주시  이도2동  126.531823
# 2236       이디야커피  제주중문관광로점       음식   커피점/카페  제주특별자치도  서귀포시   중문동  126.431777
# 2237       이디야커피      서귀포점       음식   커피점/카페  제주특별자치도  서귀포시   중앙동  126.561644
#
# ...

# %%
df_seoul_ediya =  df_ediya[df_ediya["시도명"]=="서울특별시"]
df_seoul_ediya.index =range(len(df_seoul_ediya))
print("서울 이디야 전문점 점포 수 : ", len(df_seoul_ediya))
df_seoul_ediya.head()
# Out:
# 서울 이디야 전문점 점포 수 :  474
#           상호명    지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명          경도  \
# 0       이디야커피   신길역점       음식   커피점/카페  서울특별시  영등포구  신길1동  126.918062
# 1       이디야커피   북창동점       음식   커피점/카페  서울특별시    중구   소공동  126.977556
# 2       이디야커피   라이프점       음식   커피점/카페  서울특별시  영등포구   여의동  126.939198
# 3       이디야커피    시흥점       음식   커피점/카페  서울특별시   금천구  시흥2동  126.913646
# 4  이디야커피양재AT점  양재AT점       음식   커피점/카페  서울특별시   서초구  양재2동  127.040265
#
#           위도
# 0  37.515118
# 1  37.563637
# 2  37.519544
# 3  37.449066
# 4  37.469075

# %% [markdown]
# # 커피빈

# %%
df_coffeebean =  df_coffee[df_coffee["상호명"].str.contains("커피빈")]
df_coffeebean.index =range(len(df_coffeebean))
print("전국 커피빈 전문점 점포 수 : ", len(df_coffeebean))
df_coffeebean
# Out:
# 전국 커피빈 전문점 점포 수 :  324
#              상호명          지점명 상권업종대분류명 상권업종중분류명      시도명     시군구명  행정동명  \
# 0            커피빈  코리아대학로대명거리점       음식   커피점/카페    서울특별시      종로구   혜화동
# 1            커피빈      코리아선릉역점       음식   커피점/카페    서울특별시      강남구  역삼1동
# 2    커피빈코리아낙성대역점     코리아낙성대역점       음식   커피점/카페    서울특별시      관악구   행운동
# 3            커피빈     코리아청담에스점       음식   커피점/카페    서울특별시      강남구   청담동
# 4            커피빈     코리아청담성당점       음식   커피점/카페    서울특별시      강남구   청담동
# ..           ...          ...      ...      ...      ...      ...   ...
# 319          커피빈         &마운틴       음식   커피점/카페     경상남도      통영시   사량면
# 320          커피빈          NaN       음식   커피점/카페     경상남도  창원시 진해구  웅동2동
# 321          커피빈          NaN       음식   커피점/카페     경상남도      창원시   NaN
# 322          커피빈          NaN       음식   커피점/카페     경상남도      김해시  장유3동
# 323     스팟커피빈벤더스          NaN       음식   커피점/카페  제주특별자치도      제주시  용담1동
#
#              경도         위도
# 0    127.000171  37.583149
# ...

# %%
df_seoul_coffeebean=  df_coffeebean[df_coffeebean["시도명"]=="서울특별시"]
df_seoul_coffeebean.index =range(len(df_seoul_coffeebean))
print("서울 커피빈 전문점 점포 수 : ", len(df_seoul_coffeebean))
df_seoul_coffeebean.head()
# Out:
# 서울 커피빈 전문점 점포 수 :  191
#            상호명          지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명          경도  \
# 0          커피빈  코리아대학로대명거리점       음식   커피점/카페  서울특별시  종로구   혜화동  127.000171
# 1          커피빈      코리아선릉역점       음식   커피점/카페  서울특별시  강남구  역삼1동  127.048223
# 2  커피빈코리아낙성대역점     코리아낙성대역점       음식   커피점/카페  서울특별시  관악구   행운동  126.961593
# 3          커피빈     코리아청담에스점       음식   커피점/카페  서울특별시  강남구   청담동  127.047216
# 4          커피빈     코리아청담성당점       음식   커피점/카페  서울특별시  강남구   청담동  127.050021
#
#           위도
# 0  37.583149
# 1  37.504750
# 2  37.478106
# 3  37.525250
# 4  37.519902

# %% [markdown]
# # 투썸 플레이스

# %%
df_2some =  df_coffee[df_coffee["상호명"].str.contains("투썸")]
df_2some.index =range(len(df_2some))
print("전국 투썸 전문점 점포 수 : ", len(df_2some))
df_2some
# Out:
# 전국 투썸 전문점 점포 수 :  1141
#                 상호명                지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  \
# 0            투썸플레이스              서울타워점       음식   커피점/카페    서울특별시   용산구
# 1     투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페    서울특별시   관악구
# 2            투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페    서울특별시   강남구
# 3            투썸플레이스           LG광화문빌딩점       음식   커피점/카페    서울특별시   종로구
# 4            투썸플레이스             가락시장역점       음식   커피점/카페    서울특별시   송파구
# ...             ...                ...      ...      ...      ...   ...
# 1136         투썸플레이스            제주노형DT점       음식   커피점/카페  제주특별자치도   제주시
# 1137   투썸플레이스휘슬락호텔점             휘슬락호텔점       음식   커피점/카페  제주특별자치도   제주시
# 1138         투썸플레이스              제주이도점       음식   커피점/카페  제주특별자치도   제주시
# 1139         투썸플레이스            제주애월하귀점       음식   커피점/카페  제주특별자치도   제주시
# 1140         투썸플레이스              영어도시점       음식   커피점/카페  제주특별자치도  서귀포시
#
#        행정동명          경도         위도
# 0     용산2가동  126.987856  37.551111
# ...

# %%
df_seoul_2some =  df_2some[df_2some["시도명"]=="서울특별시"]
df_seoul_2some.index =range(len(df_seoul_2some))
print("서울 투썸 전문점 점포 수 : ", len(df_seoul_2some))
df_seoul_2some.head()
# Out:
# 서울 투썸 전문점 점포 수 :  286
#              상호명                지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명   행정동명  \
# 0         투썸플레이스              서울타워점       음식   커피점/카페  서울특별시  용산구  용산2가동
# 1  투썸플레이스서울대역중앙점            서울대역중앙점       음식   커피점/카페  서울특별시  관악구    중앙동
# 2         투썸플레이스  씨제이프레시웨이강남세브란스병원점       음식   커피점/카페  서울특별시  강남구   도곡1동
# 3         투썸플레이스           LG광화문빌딩점       음식   커피점/카페  서울특별시  종로구    사직동
# 4         투썸플레이스             가락시장역점       음식   커피점/카페  서울특별시  송파구   가락본동
#
#            경도         위도
# 0  126.987856  37.551111
# 1  126.952190  37.481879
# 2  127.046294  37.492795
# 3  126.971558  37.569262
# 4  127.120826  37.493986

# %% [markdown]
# # 빽다방 커피

# %%
df_bbeak =  df_coffee[df_coffee["상호명"].str.contains("빽다방")]
df_bbeak.index =range(len(df_bbeak))
print("전국 빽다방 전문점 점포 수 : ", len(df_bbeak))
df_bbeak
# Out:
# 전국 빽다방 전문점 점포 수 :  567
#              상호명         지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명  행정동명  \
# 0    더본코리아_빽다방등촌         성당점       음식   커피점/카페    서울특별시   강서구  등촌3동
# 1    스시마이우강남역빽다방         NaN       음식   커피점/카페    서울특별시   서초구  서초4동
# 2      빽다방공덕새창로점      공덕새창로점       음식   커피점/카페    서울특별시   마포구   도화동
# 3       빽다방서초우성점       서초우성점       음식   커피점/카페    서울특별시   서초구  서초2동
# 4      빽다방잠실장미상가         NaN       음식   커피점/카페    서울특별시   송파구  잠실6동
# ..           ...         ...      ...      ...      ...   ...   ...
# 562          빽다방    제주서귀포시청점       음식   커피점/카페  제주특별자치도  서귀포시   서홍동
# 563          빽다방     제주중앙여고점       음식   커피점/카페  제주특별자치도   제주시  이도2동
# 564          빽다방    제주성산일출봉점       음식   커피점/카페  제주특별자치도  서귀포시   성산읍
# 565          빽다방  베이커리제주사수본점       음식   커피점/카페  제주특별자치도   제주시   도두동
# 566          빽다방      이중섭거리점       음식   커피점/카페  제주특별자치도  서귀포시   정방동
#
#              경도         위도
# 0    126.845764  37.560224
# 1    127.025259  37.498120
# 2    126.951822  37.542228
# ...

# %%
df_seoul_bbeak =  df_bbeak[df_bbeak["시도명"]=="서울특별시"]
df_seoul_bbeak.index =range(len(df_seoul_bbeak))
print("서울 뺵다방 전문점 점포 수 : ", len(df_seoul_bbeak))
df_seoul_bbeak.head()
# Out:
# 서울 뺵다방 전문점 점포 수 :  129
#            상호명     지점명 상권업종대분류명 상권업종중분류명    시도명 시군구명  행정동명          경도  \
# 0  더본코리아_빽다방등촌     성당점       음식   커피점/카페  서울특별시  강서구  등촌3동  126.845764
# 1  스시마이우강남역빽다방     NaN       음식   커피점/카페  서울특별시  서초구  서초4동  127.025259
# 2    빽다방공덕새창로점  공덕새창로점       음식   커피점/카페  서울특별시  마포구   도화동  126.951822
# 3     빽다방서초우성점   서초우성점       음식   커피점/카페  서울특별시  서초구  서초2동  127.029306
# 4    빽다방잠실장미상가     NaN       음식   커피점/카페  서울특별시  송파구  잠실6동  127.099289
#
#           위도
# 0  37.560224
# 1  37.498120
# 2  37.542228
# 3  37.493026
# 4  37.519810

# %% [markdown]
# # 할리스 커피

# %%
df_hollys =  df_coffee[df_coffee["상호명"].str.contains("할리스")]
df_hollys.index =range(len(df_hollys))
print("전국 할리스 전문점 점포 수 : ", len(df_hollys))
df_hollys
# Out:
# 전국 할리스 전문점 점포 수 :  707
#              상호명      지점명 상권업종대분류명 상권업종중분류명      시도명       시군구명  행정동명  \
# 0     할리스커피남부터미널      NaN       음식   커피점/카페    서울특별시        서초구  서초1동
# 1            할리스   백석예술대점       음식   커피점/카페    서울특별시        서초구  방배3동
# 2            할리스     국기원점       음식   커피점/카페    서울특별시        강남구  역삼1동
# 3    할리스커피KBS본관점   KBS본관점       음식   커피점/카페    서울특별시       영등포구   여의동
# 4          할리스커피      선릉점       음식   커피점/카페    서울특별시        강남구  대치4동
# ..           ...      ...      ...      ...      ...        ...   ...
# 702        할리스커피    진주평거점       음식   커피점/카페     경상남도        진주시   판문동
# 703  할리스커피마산터미널점   마산터미널점       음식   커피점/카페     경상남도  창원시 마산회원구  합성2동
# 704        할리스커피    밀양킹콩점       음식   커피점/카페     경상남도        밀양시   삼문동
# 705        할리스커피  협재해수욕장점       음식   커피점/카페  제주특별자치도        제주시   한림읍
# 706        할리스커피    제주이도점       음식   커피점/카페  제주특별자치도        제주시   아라동
#
#              경도         위도
# 0    127.015739  37.486724
# 1    126.996884  37.480366
# ...

# %%
df_seoul_hollys = df_hollys[df_hollys["시도명"]=="서울특별시"]
df_seoul_hollys.index = range(len(df_seoul_hollys))
print('서울 할리스 전문점 점포 수',len(df_seoul_hollys))
df_seoul_hollys
# Out:
# 서울 할리스 전문점 점포 수 200
#               상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명   행정동명          경도  \
# 0      할리스커피남부터미널     NaN       음식   커피점/카페  서울특별시   서초구   서초1동  127.015739
# 1             할리스  백석예술대점       음식   커피점/카페  서울특별시   서초구   방배3동  126.996884
# 2             할리스    국기원점       음식   커피점/카페  서울특별시   강남구   역삼1동  127.029582
# 3     할리스커피KBS본관점  KBS본관점       음식   커피점/카페  서울특별시  영등포구    여의동  126.918674
# 4           할리스커피     선릉점       음식   커피점/카페  서울특별시   강남구   대치4동  127.050514
# ..            ...     ...      ...      ...    ...   ...    ...         ...
# 195       할리스에프앤비     NaN       음식   커피점/카페  서울특별시   용산구  원효로1동  126.969703
# 196  인디스에프앤디할리스커피    광화문점       음식   커피점/카페  서울특별시    중구     명동  126.975931
# 197           할리스     응암점       음식   커피점/카페  서울특별시   은평구   신사1동  126.915314
# 198         할리스커피     반포점       음식   커피점/카페  서울특별시   서초구   반포4동  127.006816
# 199        할리스남영점     남영점       음식   커피점/카페  서울특별시   용산구   이촌1동  126.981255
#
#             위도
# 0    37.486724
# ...

# %% [markdown]
# # 메가커피

# %%
df_mega = df_coffee[df_coffee["상호명"].str.contains("메가커피")]
df_mega.index = range(len(df_mega))
print("전국 메가 전문점 점포 수 : ", len(df_mega))
df_mega
# Out:
# 전국 메가 전문점 점포 수 :  481
#         상호명      지점명 상권업종대분류명 상권업종중분류명      시도명  시군구명 행정동명          경도  \
# 0    메가커피미아    수유시장점       음식   커피점/카페    서울특별시   강북구  미아동  127.023695
# 1      메가커피      홍대점       음식   커피점/카페    서울특별시   마포구  서교동  126.921359
# 2      메가커피      NaN       음식   커피점/카페    서울특별시  동대문구  용신동  127.023642
# 3      메가커피      NaN       음식   커피점/카페    서울특별시   금천구  가산동  126.887266
# 4      메가커피   숙대입구역점       음식   커피점/카페    서울특별시   용산구  남영동  126.972201
# ..      ...      ...      ...      ...      ...   ...  ...         ...
# 476    메가커피  함덕해수욕장점       음식   커피점/카페  제주특별자치도   제주시  조천읍  126.669299
# 477    메가커피      중문점       음식   커피점/카페  제주특별자치도  서귀포시  중문동  126.423989
# 478    메가커피    제주연동점       음식   커피점/카페  제주특별자치도   제주시   연동  126.487667
# 479    메가커피    제주봉개점       음식   커피점/카페  제주특별자치도   제주시  봉개동  126.592990
# 480    메가커피    제주아라점       음식   커피점/카페  제주특별자치도   제주시  아라동  126.545393
#
#             위도
# 0    37.630164
# 1    37.552433
# 2    37.576200
# 3    37.479628
# ...

# %%
df_seoul_mega = df_mega[df_mega["시도명"]=="서울특별시"]
df_seoul_mega.index = range(len(df_seoul_mega))
print('서울 메가 전문점 점포 수',len(df_seoul_mega))
df_seoul_mega
# Out:
# 서울 메가 전문점 점포 수 86
#        상호명       지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명          경도  \
# 0   메가커피미아     수유시장점       음식   커피점/카페  서울특별시   강북구   미아동  127.023695
# 1     메가커피       홍대점       음식   커피점/카페  서울특별시   마포구   서교동  126.921359
# 2     메가커피       NaN       음식   커피점/카페  서울특별시  동대문구   용신동  127.023642
# 3     메가커피       NaN       음식   커피점/카페  서울특별시   금천구   가산동  126.887266
# 4     메가커피    숙대입구역점       음식   커피점/카페  서울특별시   용산구   남영동  126.972201
# ..     ...       ...      ...      ...    ...   ...   ...         ...
# 81  메가커피등촌       성당점       음식   커피점/카페  서울특별시   강서구  등촌3동  126.845520
# 82    메가커피  신대방삼거리역점       음식   커피점/카페  서울특별시   동작구   대방동  126.927878
# 83    메가커피       NaN       음식   커피점/카페  서울특별시   용산구  한강로동  126.969979
# 84    메가커피    은평뉴타운점       음식   커피점/카페  서울특별시   은평구   진관동  126.919103
# 85    메가커피    목동파라곤점       음식   커피점/카페  서울특별시   양천구   목1동  126.875058
#
#            위도
# 0   37.630164
# 1   37.552433
# 2   37.576200
# 3   37.479628
# 4   37.543056
# ...

# %% [markdown]
# # 전국 커피 매장 점포수 알아보기

# %%
print("전국 스벅 전문점 점포 수 : ", len(df_starbucks))
print("전국 이디야 전문점 점포 수 : ", len(df_ediya))
print("전국 투썸 전문점 점포 수 : ", len(df_2some))
print("전국 빽다방 전문점 점포 수 : ", len(df_bbeak))
print("전국 커피빈 전문점 점포 수 : ", len(df_coffeebean))
print("전국 메가 전문점 점포 수 : ", len(df_mega))
print("전국 할리스 전문점 점포 수 : ", len(df_hollys))
# Out:
# 전국 스벅 전문점 점포 수 :  1613
# 전국 이디야 전문점 점포 수 :  2238
# 전국 투썸 전문점 점포 수 :  1141
# 전국 빽다방 전문점 점포 수 :  567
# 전국 커피빈 전문점 점포 수 :  324
# 전국 메가 전문점 점포 수 :  481
# 전국 할리스 전문점 점포 수 :  707

# %%
# 서울 주요 커피 브랜드 입점 비율

print("이디야: %.3f%%" % (len(df_seoul_ediya)/ len(df_seoul_coffe)*100))
print("스타벅스: %.3f%%" % (len(df_seoul_starbucks)/ len(df_seoul_coffe)*100))
print("투썸: %.3f%%" % (len(df_seoul_2some)/ len(df_seoul_coffe)*100))
print("할리스: %.3f%%" % (len(df_seoul_hollys)/ len(df_seoul_coffe)*100))
print("빽다방: %.3f%%" % (len(df_seoul_bbeak)/ len(df_seoul_coffe)*100))
print("커피빈: %.3f%%" % (len(df_seoul_coffeebean)/ len(df_seoul_coffe)*100))
print("메가: %.3f%%" % (len(df_seoul_mega)/ len(df_seoul_coffe)*100))
# Out:
# 이디야: 2.131%
# 스타벅스: 2.289%
# 투썸: 1.286%
# 할리스: 0.899%
# 빽다방: 0.580%
# 커피빈: 0.859%
# 메가: 0.387%

# %% [markdown]
# # 주요 5대 커피점 입점 비율 알아보기

# %%
print("주요 5대 커피 전국 입점 비율: %.3f%% "
      % ((len(df_starbucks)+len(df_ediya)+len(df_2some)+len(df_bbeak)+len(df_hollys)) /len(df_coffee) * 100))
print("이디야: %.3f%%" % (len(df_ediya)/ len(df_coffee)*100))
print("스타벅스: %.3f%%" % (len(df_starbucks)/ len(df_coffee)*100))
print("투썸: %.3f%%" % (len(df_2some)/ len(df_coffee)*100))
print("할리스: %.3f%%" % (len(df_hollys)/ len(df_coffee)*100))
print("빽다방: %.3f%%" % (len(df_bbeak)/ len(df_coffee)*100))
# Out:
# 주요 5대 커피 전국 입점 비율: 5.511%
# 이디야: 1.968%
# 스타벅스: 1.419%
# 투썸: 1.003%
# 할리스: 0.622%
# 빽다방: 0.499%

# %%
print("주요 5대 커피 서울 입점 비율: %.3f%% "
      % ((len(df_starbucks)+len(df_seoul_ediya)+len(df_seoul_2some)+len(df_seoul_bbeak)+len(df_seoul_hollys)) /len(df_seoul_coffe) * 100))

print("이디야: %.3f%%" % (len(df_seoul_ediya)/ len(df_seoul_coffe)*100))
print("스타벅스: %.3f%%" % (len(df_seoul_starbucks)/ len(df_seoul_coffe)*100))
print("투썸: %.3f%%" % (len(df_seoul_2some)/ len(df_seoul_coffe)*100))
print("할리스: %.3f%%" % (len(df_seoul_hollys)/ len(df_seoul_coffe)*100))
print("빽다방: %.3f%%" % (len(df_seoul_bbeak)/ len(df_seoul_coffe)*100))
# Out:
# 주요 5대 커피 서울 입점 비율: 12.150%
# 이디야: 2.131%
# 스타벅스: 2.289%
# 투썸: 1.286%
# 할리스: 0.899%
# 빽다방: 0.580%

# %%
print("***주요 5대 커피 브랜드 서울 입점 비율***")

print("이디야: %.3f%%" % (len(df_seoul_ediya)/ len(df_ediya)*100))
print("스타벅스: %.3f%%" % (len(df_seoul_starbucks)/ len(df_starbucks)*100))
print("투썸: %.3f%%" % (len(df_seoul_2some)/ len(df_2some)*100))
print("할리스: %.3f%%" % (len(df_seoul_hollys)/ len(df_hollys)*100))
print("빽다방: %.3f%%" % (len(df_seoul_bbeak)/ len(df_bbeak)*100))
# Out:
# ***주요 5대 커피 브랜드 서울 입점 비율***
# 이디야: 21.180%
# 스타벅스: 31.556%
# 투썸: 25.066%
# 할리스: 28.289%
# 빽다방: 22.751%

# %%
starbucks_gu = df_seoul_starbucks.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
starbucks_gu = starbucks_gu.reset_index()
starbucks_gu = starbucks_gu.set_index('시군구명')


ediya_gu = df_seoul_ediya.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
ediya_gu = ediya_gu.reset_index()
ediya_gu = ediya_gu.set_index('시군구명')

bbeak_gu = df_seoul_bbeak.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
bbeak_gu = bbeak_gu.reset_index()
bbeak_gu = bbeak_gu.set_index('시군구명')

twosome_gu= df_seoul_2some.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
twosome_gu = twosome_gu.reset_index()
twosome_gu = twosome_gu.set_index('시군구명')

hollys_gu = df_seoul_hollys.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
hollys_gu = hollys_gu.reset_index()
hollys_gu = hollys_gu.set_index('시군구명')

mega_gu = df_seoul_mega.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
mega_gu = mega_gu.reset_index()
mega_gu = mega_gu.set_index('시군구명')

coffeebean_gu = df_seoul_coffeebean.groupby('시군구명')['상호명'].count().to_frame().sort_values(by='상호명',ascending=False)
coffeebean_gu = coffeebean_gu.reset_index()
coffeebean_gu = coffeebean_gu.set_index('시군구명')


seoul_gu = pd.concat([ediya_gu,starbucks_gu,bbeak_gu,twosome_gu,hollys_gu,mega_gu,coffeebean_gu], axis = 0)

# %% [markdown]
# # 주요 5대 커피 서울 입점 비율 시각화

# %%
ediya_rate = (len(df_seoul_ediya)/ len(df_ediya)*100)
starbucks_rate = (len(df_seoul_starbucks)/ len(df_starbucks)*100)
twosome_rate=(len(df_seoul_2some)/ len(df_2some)*100)
hollys_rate=(len(df_seoul_hollys)/ len(df_hollys)*100)
bbeak_rate=(len(df_seoul_bbeak)/ len(df_bbeak)*100)

X = ["이디야","스타벅스","투썸", "할리스","뺵다방"]
y = [ediya_rate, starbucks_rate, twosome_rate, hollys_rate, bbeak_rate]

plt.figure(figsize=(12,12))
plt.title("주요 5대 커피 서울 입점 비율", fontdict={"fontsize":20})
sns.barplot(x=X, y=y)
plt.savefig("coffee_barplot.png")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52964 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ediya_rate = (len(df_seoul_ediya)/ len(df_ediya)*100)
starbucks_rate = (len(df_seoul_starbucks)/ len(df_starbucks)*100)
twosome_rate=(len(df_seoul_2some)/ len(df_2some)*100)
hollys_rate=(len(df_seoul_hollys)/ len(df_hollys)*100)
bbeak_rate=(len(df_seoul_bbeak)/ len(df_bbeak)*100)
coffeebean_rate= (len(df_seoul_coffeebean)/ len(df_coffeebean)*100)
mega_rate=(len(df_seoul_mega)/ len(df_mega)*100)


X = ["이디야","스타벅스","투썸", "할리스","뺵다방","커피빈","메가"]
y = [ediya_rate, starbucks_rate, twosome_rate, hollys_rate, bbeak_rate, coffeebean_rate, mega_rate]

plt.figure(figsize=(12,12))
plt.title("주요 커피브랜드 서울 입점 비율", fontdict={"fontsize":20})
sns.barplot(x=X, y=y)
plt.savefig("coffee_barplot.png")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52964 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ediya_rate = (len(df_ediya)/ len(df_coffee)*100)
starbucks_rate = (len(df_starbucks)/ len(df_coffee)*100)
twosome_rate=(len(df_2some)/ len(df_coffee)*100)
hollys_rate=(len(df_hollys)/ len(df_coffee)*100)
bbeak_rate=(len(df_bbeak)/ len(df_coffee)*100)
coffeebean_rate= (len(df_coffeebean)/ len(df_coffee)*100)
mega_rate=(len(df_mega)/ len(df_coffee)*100)


X = ["이디야","스타벅스","투썸", "할리스","뺵다방","커피빈","메가"]
y = [ediya_rate, starbucks_rate, twosome_rate, hollys_rate, bbeak_rate, coffeebean_rate, mega_rate]

plt.figure(figsize=(12,12))
plt.title("주요 커피브랜드 전국입점 비율", fontdict={"fontsize":20})
sns.barplot(x=X, y=y)
plt.savefig("coffee_barplot.png")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52964 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 10))
df_seoul_coffe.loc[df_seoul_coffe['상권업종중분류명'] == '커피점/카페'].groupby('시군구명')['상권업종대분류명'].count()\
                                                     .sort_values().plot(kind='barh', color='cyan')
plt.yticks(fontsize=12)
plt.title('서울시 자치구별 커피점/카페 업종수')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 스타벅스
starbucks = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('스타벅스', na=False)].reset_index(drop=True)
starbucks['브랜드명'] = '스타벅스'
df_seoul_starbucks = starbucks[['경도', '위도','상호명','시군구명' ,'브랜드명']]

# 이디야
ediya = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('이디야', na=False)].reset_index(drop=True)
ediya['브랜드명'] = '이디야'
df_seoul_ediya = ediya[['경도', '위도','상호명','시군구명','브랜드명']]

#투썸
twosome = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('투썸', na=False)].reset_index(drop=True)
twosome['브랜드명'] = '투썸'
df_seoul_2some = twosome[['경도', '위도','상호명','시군구명','브랜드명']]

#할리스
hollys = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('할리스', na=False)].reset_index(drop=True)
hollys['브랜드명'] = '할리스'
df_seoul_hollys = hollys[['경도', '위도','상호명','시군구명','브랜드명']]

#커피빈
coffeebean = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('커피빈', na=False)].reset_index(drop=True)
coffeebean['브랜드명'] = '커피빈'
df_seoul_coffeebean = coffeebean[['경도', '위도','상호명','시군구명','브랜드명']]

#커피빈
bbeak = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('빽다방', na=False)].reset_index(drop=True)
bbeak['브랜드명'] = '빽다방'
df_seoul_bbeak = bbeak[['경도', '위도','상호명','시군구명','브랜드명']]

#메가
mega = df_seoul_coffe[df_seoul_coffe['상호명'].str.contains('메가', na=False)].reset_index(drop=True)
mega['브랜드명'] = '메가'
df_seoul_mega = mega[['경도', '위도','상호명','시군구명','브랜드명']]

df_seoul_maincoffee = pd.concat([ediya,starbucks,twosome,hollys,bbeak,coffeebean,mega], axis = 0)


df_seoul_maincoffee
# Out:
#             상호명     지점명 상권업종대분류명 상권업종중분류명    시도명  시군구명  행정동명          경도  \
# 0         이디야커피    신길역점       음식   커피점/카페  서울특별시  영등포구  신길1동  126.918062
# 1         이디야커피    북창동점       음식   커피점/카페  서울특별시    중구   소공동  126.977556
# 2         이디야커피    라이프점       음식   커피점/카페  서울특별시  영등포구   여의동  126.939198
# 3         이디야커피     시흥점       음식   커피점/카페  서울특별시   금천구  시흥2동  126.913646
# 4    이디야커피양재AT점   양재AT점       음식   커피점/카페  서울특별시   서초구  양재2동  127.040265
# ..          ...     ...      ...      ...    ...   ...   ...         ...
# 217     메가엠지씨커피   상계보람점       음식   커피점/카페  서울특별시   노원구  상계5동  127.066566
# 218     메가엠지씨커피     석관점       음식   커피점/카페  서울특별시   성북구   석관동  127.060957
# 219     메가엠지씨커피  서울시립대점       음식   커피점/카페  서울특별시  동대문구  전농1동  127.053601
# 220        메가커피  은평뉴타운점       음식   커피점/카페  서울특별시   은평구   진관동  126.919103
# 221        메가커피  목동파라곤점       음식   커피점/카페  서울특별시   양천구   목1동  126.875058
#
#             위도 브랜드명
# 0    37.515118  이디야
# 1    37.563637  이디야
# 2    37.519544  이디야
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = df_seoul_coffe, y='시군구명')
plt.title(" 서울커피점 입점 비율", fontdict={"fontsize":20})

plt.figure(figsize=(10, 6))
sns.countplot(data = df_seoul_maincoffee, y='시군구명')
plt.title("주요 커피브랜드 서울 입점 비율", fontdict={"fontsize":20})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52964 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(8,8))
plt.pie(df_seoul_coffe['시군구명'].value_counts().values,
        labels=df_seoul_coffe['시군구명'].value_counts().index,
        autopct='%d%%',
        colors=sns.color_palette('hls',len(df_seoul_coffe['시군구명'].value_counts().index)),
        textprops={'fontsize':12})
plt.axis('equal')
plt.title("커피점 서울 입점 비율", fontdict={"fontsize":20}, pad=50)
plt.savefig("커피점 서울 입점 비율.png")


plt.figure(figsize=(8,8))
plt.pie(df_seoul_maincoffee['시군구명'].value_counts().values,
        labels=df_seoul_maincoffee['시군구명'].value_counts().index,
        autopct='%d%%',
        colors=sns.color_palette('hls',len(df_seoul_maincoffee['시군구명'].value_counts().index)),
        textprops={'fontsize':12})
plt.axis('equal')
plt.title("주요 브랜드 커피점 서울 입점 비율", fontdict={"fontsize":20}, pad=50)
plt.savefig("주요 브랜드 커피점 서울 입점 비율.png")
plt.show()

# %%
sns.scatterplot (data=df_seoul_maincoffee, x="경도",y="위도", hue='브랜드명')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
